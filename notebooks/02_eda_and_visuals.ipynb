# %% [markdown]
# # 📈 Exploratory Data Analysis & Visualizations
#
# Comprehensive visual analysis including:
# - UGI distribution analysis
# - Top performing cities
# - Correlation analysis
# - Regional comparisons
# - Multi-city radar charts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("📊 Visualization libraries loaded!")

# %% [markdown]
# ## 📊 Load Processed Data

# %%
# df = pd.read_csv('../data/processed/cities_data.csv')
# print(f"Dataset loaded: {df.shape}")
# df.head()

# %% [markdown]
# ## 📊 1. UGI Distribution Analysis

# %%
# Histogram: UGI Score Distribution
# fig, ax = plt.subplots(figsize=(10, 6))
# plt.hist(df['UGI'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
# plt.title('Distribution of UGI Scores Across Indian Cities', fontsize=16, fontweight='bold')
# plt.xlabel('UGI Score')
# plt.ylabel('Number of Cities')
# plt.grid(True, alpha=0.3)
# plt.show()

# %% [markdown]
# ## 🏆 2. Top 15 Cities Analysis

# %%
# Bar Chart: Top 15 Cities by UGI
# top_15 = df.nlargest(15, 'UGI')
# 
# fig, ax = plt.subplots(figsize=(12, 8))
# bars = plt.barh(top_15['City'], top_15['UGI'], color='coral')
# plt.title('Top 15 Indian Cities by UGI Score', fontsize=16, fontweight='bold')
# plt.xlabel('UGI Score')
# plt.gca().invert_yaxis()
# 
# # Add value labels
# for bar in bars:
#     width = bar.get_width()
#     plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, 
#              f'{width:.1f}', ha='left', va='center')
# 
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ✈️ 3. Connectivity vs Economy Analysis

# %%
# Scatter Plot: Daily Flights vs GDP
# fig = px.scatter(df, x='DailyFlights', y='GDP', 
#                  size='Population', color='UGI',
#                  hover_name='City',
#                  title='City Connectivity vs Economic Performance',
#                  labels={'DailyFlights': 'Daily Flights', 'GDP': 'GDP (Billions USD)'})
# fig.show()

# %% [markdown]
# ## 🔥 4. Pillar Correlation Heatmap

# %%
# Correlation matrix for 5 pillars
# pillar_cols = ['Connectivity_Score', 'Economy_Score', 'Demographics_Score', 
#                'Infrastructure_Score', 'Digital_Score']
# 
# corr_matrix = df[pillar_cols].corr()
# 
# fig, ax = plt.subplots(figsize=(10, 8))
# sns.heatmap(corr_matrix, annot=True, cmap='RdYlBu_r', center=0,
#             square=True, linewidths=0.5)
# plt.title('Correlation Between Development Pillars', fontsize=16, fontweight='bold')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 🗺️ 5. Regional Performance Analysis

# %%
# Box Plot: UGI by Region
# fig, ax = plt.subplots(figsize=(12, 6))
# sns.boxplot(data=df, x='Region', y='UGI', palette='Set2')
# plt.title('UGI Score Distribution by Region', fontsize=16, fontweight='bold')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 🎯 6. Multi-City Radar Comparison

# %%
# Radar Chart: Top 3 Cities Comparison
# top_3_cities = ['Mumbai', 'Delhi', 'Bangalore']  # Example
# pillars = ['Connectivity', 'Economy', 'Demographics', 'Infrastructure', 'Digital']
# 
# fig = go.Figure()
# 
# for city in top_3_cities:
#     city_data = df[df['City'] == city]
#     values = [city_data[f'{pillar}_Score'].iloc[0] for pillar in pillars]
#     values += values[:1]  # Complete the circle
#     
#     fig.add_trace(go.Scatterpolar(
#         r=values,
#         theta=pillars + [pillars[0]],
#         fill='toself',
#         name=city
#     ))
# 
# fig.update_layout(
#     polar=dict(
#         radialaxis=dict(visible=True, range=[0, 100])
#     ),
#     title="Top 3 Cities: Pillar Comparison",
#     showlegend=True
# )
# 
# fig.show()

# %% [markdown]
# ## 📊 7. UGI Ranking Analysis

# %%
# Line Plot: UGI Score by Rank
# df_sorted = df.sort_values('UGI', ascending=False).reset_index(drop=True)
# df_sorted['Rank'] = range(1, len(df_sorted) + 1)
# 
# fig, ax = plt.subplots(figsize=(12, 6))
# plt.plot(df_sorted['Rank'], df_sorted['UGI'], marker='o', linewidth=2, markersize=4)
# plt.title('UGI Score Distribution by City Ranking', fontsize=16, fontweight='bold')
# plt.xlabel('City Rank')
# plt.ylabel('UGI Score')
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 📋 Summary Statistics

# %%
# Key insights and statistics
# print("🎯 KEY INSIGHTS:")
# print(f"Average UGI Score: {df['UGI'].mean():.1f}")
# print(f"Highest UGI: {df['UGI'].max():.1f} ({df.loc[df['UGI'].idxmax(), 'City']})")
# print(f"Lowest UGI: {df['UGI'].min():.1f} ({df.loc[df['UGI'].idxmin(), 'City']})")
# print(f"Standard Deviation: {df['UGI'].std():.1f}")
